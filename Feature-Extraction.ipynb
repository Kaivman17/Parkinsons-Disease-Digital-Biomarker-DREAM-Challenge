# %% [markdown]
# # Extracting Features from Raw Walking Data

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sb

# %%
import synapseclient
# If you have your config file set up you can run:
syn = synapseclient.login()
# Out:
# Welcome, Kaivon Ahmad!

# %%
demo_query = syn.tableQuery("SELECT * FROM syn10146552")

# Convert to dataframe
demographics_df = demo_query.asDataFrame()

# %%
demographics_df.head()
# Out:
#                                  recordId  \
# 0_0  bbb003a9-5c7b-4d66-a1d3-bcd1430edbb7
# 1_0  05258304-77f7-4761-bc58-52dc743e44cd
# 2_0  b331ff56-c6d9-430a-bc6c-b6f52d2d8e9f
# 3_0  0bc6fe52-d24d-419c-97be-91a6ba32839b
# 4_0  6ef0da29-24cd-4391-8ca4-9e20ced8dfa0
#
#                                healthCode      createdOn  \
# 0_0  639e8a78-3631-4231-bda1-c911c1b169e5  1425904649000
# 1_0  52fe366a-2a9f-4260-9fb1-0fbc637a6cf4  1425926191000
# 2_0  67bdd316-26fc-4fc7-8431-bf9f41a649dd  1425926604000
# 3_0  af441f87-c447-4c3c-8e00-72751aff2360  1425927330000
# 4_0  340260f8-644a-4670-8a39-bc0729310343  1425927378000
#
#                appVersion        phoneInfo   age are-caretaker  \
# 0_0  version 1.0, build 7         iPhone 6  24.0         False
# 1_0  version 1.0, build 7  iPhone 5s (GSM)  38.0         False
# 2_0  version 1.0, build 7    iPhone 6 Plus  32.0         False
# 3_0  version 1.0, build 7         iPhone 6  24.0         False
# 4_0  version 1.0, build 7         iPhone 6  35.0         False
#
#     deep-brain-stimulation  diagnosis-year              education  \
# 0_0                  False             NaN           Some college
# 1_0                  False             NaN   Some graduate school
# 2_0                  False             NaN  2-year college degree
# 3_0                  False             NaN           Some college
# 4_0                  False             NaN        Doctoral Degree
#
#          ...       packs-per-day past-participation phone-usage  \
# 0_0      ...                 NaN              False        true
# 1_0      ...                 NaN              False        true
# 2_0      ...                 1.0              False        true
# 3_0      ...                 NaN              False        true
# 4_0      ...                 NaN              False        true
#
#     professional-diagnosis                  race  smartphone smoked surgery  \
# 0_0                  False  "White or Caucasian"   Very easy  False   False
# 1_0                  False  "White or Caucasian"   Very easy  False     NaN
# 2_0                  False  "White or Caucasian"   Very easy   True     NaN
# 3_0                  False     "Latino/Hispanic"   Very easy   True   False
# 4_0                  False  "White or Caucasian"   Very easy  False   False
#
#     video-usage  years-smoking
# 0_0       False            NaN
# 1_0        True            NaN
# 2_0        True            8.0
# 3_0        True            0.0
# 4_0        True            NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# # Computational Limitations

# %% [markdown]
# The size of the entire dataset that can be obtained from the synapse API is around 36,000. Each patient is an instance and each patient contains it's own json file that includes walking device data. I attemped to extract features with the entire dataset but it was taking an indefinite amount of time for my computer to go through each row, open the json file and extract the different features. Due to this inability, I was only able to use 2,000 instances from the dataset. The following notebooks will be mostly for proof of concept with the greater intention being to download the entire dataset and see if the analysis can be further scaled.

# %%
healthcode_list = ", ".join( repr(i) for i in demographics_df["healthCode"])

# %%
# Query 'walking training table' for walk data recordIDs and healthCodes. 
INPUT_WALKING_ACTIVITY_TABLE_SYNID = "syn10146553"
actv_walking_syntable = syn.tableQuery(('SELECT "recordId", "healthCode", "deviceMotion_walking_outbound.json.items" FROM {0} WHERE healthCode IN ({1}) AND "deviceMotion_walking_outbound.json.items" is not null limit 2000').format(INPUT_WALKING_ACTIVITY_TABLE_SYNID, healthcode_list))
actv_walking = actv_walking_syntable.asDataFrame()
actv_walking['idx'] = actv_walking.index

# %%
actv_walking.head()
# Out:
#                                      recordId  \
# 1401_0   a3e54d84-360e-4e8a-9534-de188d5fa9e1
# 19613_9  27d5ffdd-536e-4f2d-b478-74bbd520e9f7
# 2570_1   cdd76ffc-9607-4106-b806-2fa29ad282f4
# 2573_1   ba735eb0-0639-4392-8d4d-f87b06c7b7e6
# 2574_1   2344a520-81df-4166-9f63-09343c502a21
#
#                                    healthCode  \
# 1401_0   000240d1-1110-4dd2-a2d0-e344c37efd68
# 19613_9  00081bd9-9abd-4003-b035-de6cc3e8c922
# 2570_1   00372eda-3796-481b-96f7-f37e8e600904
# 2573_1   00372eda-3796-481b-96f7-f37e8e600904
# 2574_1   00372eda-3796-481b-96f7-f37e8e600904
#
#          deviceMotion_walking_outbound.json.items      idx
# 1401_0                                    2408193   1401_0
# 19613_9                                   3253717  19613_9
# 2570_1                                    2518106   2570_1
# 2573_1                                    2578074   2573_1
# 2574_1                                    2502847   2574_1

# %%
import json

# bulk download walk JSON files containing sensor data
walk_json_files = syn.downloadTableColumns(actv_walking_syntable, "deviceMotion_walking_outbound.json.items")
items = walk_json_files.items()

# create pandas dataframe of JSON filepaths and filehandleIDs
walk_json_files_temp = pd.DataFrame({"deviceMotion_walking_outbound.json.items": [i[0] for i in items], "outbound_walk_json_file": [i[1] for i in items]})

# convert ints to strings for merging
actv_walking["deviceMotion_walking_outbound.json.items"] = actv_walking["deviceMotion_walking_outbound.json.items"].astype(str)

# merge IDs/healthCodes with JSON data
actv_walk_temp = pd.merge(actv_walking, walk_json_files_temp, on="deviceMotion_walking_outbound.json.items")
# Out:
# Downloading 0 files, 2000 cached locally

# %%
actv_walk_temp.head()
# Out:
#                                recordId                            healthCode  \
# 0  a3e54d84-360e-4e8a-9534-de188d5fa9e1  000240d1-1110-4dd2-a2d0-e344c37efd68
# 1  27d5ffdd-536e-4f2d-b478-74bbd520e9f7  00081bd9-9abd-4003-b035-de6cc3e8c922
# 2  cdd76ffc-9607-4106-b806-2fa29ad282f4  00372eda-3796-481b-96f7-f37e8e600904
# 3  ba735eb0-0639-4392-8d4d-f87b06c7b7e6  00372eda-3796-481b-96f7-f37e8e600904
# 4  2344a520-81df-4166-9f63-09343c502a21  00372eda-3796-481b-96f7-f37e8e600904
#
#   deviceMotion_walking_outbound.json.items      idx  \
# 0                                  2408193   1401_0
# 1                                  3253717  19613_9
# 2                                  2518106   2570_1
# 3                                  2578074   2573_1
# 4                                  2502847   2574_1
#
#                              outbound_walk_json_file
# 0  /Users/kaivon123/.synapseCache/193/2408193/dev...
# 1  /Users/kaivon123/.synapseCache/717/3253717/dev...
# 2  /Users/kaivon123/.synapseCache/106/2518106/dev...
# 3  /Users/kaivon123/.synapseCache/74/2578074/devi...
# 4  /Users/kaivon123/.synapseCache/847/2502847/dev...

# %% [markdown]
# # Features Chosen

# %% [markdown]
# For patient's acceleration in the X, Y, and Z axis, each axis will have the following:
# -  mean of the acceleration
# -  standard deviation of the acceleration
# -  median of the acceleration
# -  skew of the acceleration
# -  kurtosis of the acceleration
# -  range of the acceleration
# -  variation of the acceleration

# %%
import scipy.stats.stats as st

# get average(mean) x-coordinate UserAcceleration for each file
x_accel = [] # initialize empty list for storing x-acceleration values
avg_x_accel = [] # initialize empty list for different features
std_x_accel = []
med_x_accel = []
skew_x_accel = []
kurt_x_accel = []
range_x_accel = []
variation_x_accel = []

# function for computing range
def get_range(accel_list):
    min_val = min(accel_list)
    max_val = max(accel_list)
    return max_val - min_val

# %%
# loop through each row in dataframe to read in json file
# grab the userAcceleration x-values and calculate the means

def get_features(axis):

    axis_accel = [] # initialize empty list for storing acceleration values of axis
    avg_accel = [] # initialize empty list for different features
    std_accel = []
    med_accel = []
    skew_accel = []
    kurt_accel = []
    range_accel = []
    variation_accel = []

    for row in actv_walk_temp["outbound_walk_json_file"]: 
        with open(row) as json_data:
            data = json.load(json_data)
            for item in data:
                acceleration = item.get("userAcceleration").get(axis)
                axis_accel.append(acceleration)

            avg = np.mean(axis_accel)
            std = np.std(axis_accel)
            med = np.median(axis_accel)
            skew = st.skew(axis_accel)
            kurt = st.kurtosis(axis_accel)
            xrange = get_range(axis_accel)
            variation = st.variation(axis_accel)
            
            avg_accel.append(avg)
            std_accel.append(std)
            med_accel.append(med)
            skew_accel.append(skew)
            kurt_accel.append(kurt)
            range_accel.append(xrange)
            variation_accel.append(variation)
            
    return avg_accel, std_accel, med_accel, skew_accel, kurt_accel, range_accel, variation_accel

# %%
avg_x_accel, std_x_accel, med_x_accel, skew_x_accel, kurt_x_accel, range_x_accel, variation_x_accel = get_features('x')

# %%
# create new column in dataframe for each feature
actv_walk_temp["meanXaccel"] = avg_x_accel
actv_walk_temp["medianXaccel"] = med_x_accel
actv_walk_temp["stdXaccel"] = std_x_accel
actv_walk_temp["skewXaccel"] = skew_x_accel
actv_walk_temp["kurtXaccel"] = kurt_x_accel
actv_walk_temp["rangeXaccel"] = range_x_accel
actv_walk_temp["variationXaccel"] = variation_x_accel


# Remove unnecessary columns
actv_walk = actv_walk_temp.drop(["deviceMotion_walking_outbound.json.items", "idx", "outbound_walk_json_file"], axis=1)

# %%
actv_walk.head()
# Out:
#                                recordId                            healthCode  \
# 0  a3e54d84-360e-4e8a-9534-de188d5fa9e1  000240d1-1110-4dd2-a2d0-e344c37efd68
# 1  27d5ffdd-536e-4f2d-b478-74bbd520e9f7  00081bd9-9abd-4003-b035-de6cc3e8c922
# 2  cdd76ffc-9607-4106-b806-2fa29ad282f4  00372eda-3796-481b-96f7-f37e8e600904
# 3  ba735eb0-0639-4392-8d4d-f87b06c7b7e6  00372eda-3796-481b-96f7-f37e8e600904
# 4  2344a520-81df-4166-9f63-09343c502a21  00372eda-3796-481b-96f7-f37e8e600904
#
#    meanXaccel  medianXaccel  stdXaccel  skewXaccel  kurtXaccel  rangeXaccel  \
# 0   -0.060817     -0.039582   0.251105   -0.438470    0.141505     1.508230
# 1   -0.015293      0.019290   0.205124   -0.854834    1.367009     1.521156
# 2    0.013353      0.023553   0.206104   -0.969447    4.550264     2.571121
# 3    0.016124      0.023198   0.192878   -0.936322    4.949377     2.571121
# 4    0.013815      0.019293   0.198090   -0.664648    4.381479     2.674647
#
#    variationXaccel
# 0        -4.128884
# 1       -13.413365
# 2        15.434469
# 3        11.962509
# 4        14.338761

# %%
# extract y access features

avg_y_accel, std_y_accel, med_y_accel, skew_y_accel, kurt_y_accel, range_y_accel, variation_y_accel = get_features('y')

# %%
# add y features as columns

actv_walk["meanYaccel"] = avg_y_accel
actv_walk["medianYaccel"] = med_y_accel
actv_walk["stdYaccel"] = std_y_accel
actv_walk["skewYaccel"] = skew_y_accel
actv_walk["kurtYaccel"] = kurt_y_accel
actv_walk["rangeYaccel"] = range_y_accel
actv_walk["variationYaccel"] = variation_y_accel

# %%
actv_walk.head()
# Out:
#                                recordId                            healthCode  \
# 0  a3e54d84-360e-4e8a-9534-de188d5fa9e1  000240d1-1110-4dd2-a2d0-e344c37efd68
# 1  27d5ffdd-536e-4f2d-b478-74bbd520e9f7  00081bd9-9abd-4003-b035-de6cc3e8c922
# 2  cdd76ffc-9607-4106-b806-2fa29ad282f4  00372eda-3796-481b-96f7-f37e8e600904
# 3  ba735eb0-0639-4392-8d4d-f87b06c7b7e6  00372eda-3796-481b-96f7-f37e8e600904
# 4  2344a520-81df-4166-9f63-09343c502a21  00372eda-3796-481b-96f7-f37e8e600904
#
#    meanXaccel  medianXaccel  stdXaccel  skewXaccel  kurtXaccel  rangeXaccel  \
# 0   -0.060817     -0.039582   0.251105   -0.438470    0.141505     1.508230
# 1   -0.015293      0.019290   0.205124   -0.854834    1.367009     1.521156
# 2    0.013353      0.023553   0.206104   -0.969447    4.550264     2.571121
# 3    0.016124      0.023198   0.192878   -0.936322    4.949377     2.571121
# 4    0.013815      0.019293   0.198090   -0.664648    4.381479     2.674647
#
#    variationXaccel  meanYaccel  medianYaccel  stdYaccel  skewYaccel  \
# 0        -4.128884    0.048314      0.021201   0.315285    0.319682
# 1       -13.413365    0.050700      0.029125   0.267536    0.547424
# 2        15.434469    0.047635      0.020974   0.230869    0.571332
# 3        11.962509    0.056733      0.024706   0.226478    0.709988
# 4        14.338761    0.048095      0.019794   0.246758    0.681993
#
#    kurtYaccel  rangeYaccel  variationYaccel
# 0   -0.210016     1.895134         6.525710
# 1    1.101485     1.910760         5.276845
# 2    2.337877     2.653296         4.846593
# 3    2.618261     2.653296         3.992016
# 4    3.859799     3.030658         5.130650

# %%
# extract z features

avg_z_accel, std_z_accel, med_z_accel, skew_z_accel, kurt_z_accel, range_z_accel, variation_z_accel = get_features('z')

# %%
# add z features as columns

actv_walk["meanZaccel"] = avg_z_accel
actv_walk["medianZaccel"] = med_z_accel
actv_walk["stdZaccel"] = std_z_accel
actv_walk["skewZaccel"] = skew_z_accel
actv_walk["kurtZaccel"] = kurt_z_accel
actv_walk["rangeZaccel"] = range_z_accel
actv_walk["variationZaccel"] = variation_z_accel

# %%
actv_walk.head()
# Out:
#                                recordId                            healthCode  \
# 0  a3e54d84-360e-4e8a-9534-de188d5fa9e1  000240d1-1110-4dd2-a2d0-e344c37efd68
# 1  27d5ffdd-536e-4f2d-b478-74bbd520e9f7  00081bd9-9abd-4003-b035-de6cc3e8c922
# 2  cdd76ffc-9607-4106-b806-2fa29ad282f4  00372eda-3796-481b-96f7-f37e8e600904
# 3  ba735eb0-0639-4392-8d4d-f87b06c7b7e6  00372eda-3796-481b-96f7-f37e8e600904
# 4  2344a520-81df-4166-9f63-09343c502a21  00372eda-3796-481b-96f7-f37e8e600904
#
#    meanXaccel  medianXaccel  stdXaccel  skewXaccel  kurtXaccel  rangeXaccel  \
# 0   -0.060817     -0.039582   0.251105   -0.438470    0.141505     1.508230
# 1   -0.015293      0.019290   0.205124   -0.854834    1.367009     1.521156
# 2    0.013353      0.023553   0.206104   -0.969447    4.550264     2.571121
# 3    0.016124      0.023198   0.192878   -0.936322    4.949377     2.571121
# 4    0.013815      0.019293   0.198090   -0.664648    4.381479     2.674647
#
#    variationXaccel  meanYaccel       ...         kurtYaccel  rangeYaccel  \
# 0        -4.128884    0.048314       ...          -0.210016     1.895134
# 1       -13.413365    0.050700       ...           1.101485     1.910760
# 2        15.434469    0.047635       ...           2.337877     2.653296
# 3        11.962509    0.056733       ...           2.618261     2.653296
# 4        14.338761    0.048095       ...           3.859799     3.030658
#
#    variationYaccel  meanZaccel  medianZaccel  stdZaccel  skewZaccel  \
# 0         6.525710   -0.104390     -0.152150   0.475797    0.726143
# 1         5.276845   -0.009990      0.011845   0.388474    0.143198
# 2         4.846593   -0.098005     -0.091900   0.420515   -1.091197
# 3         3.992016   -0.068101     -0.036225   0.425813   -1.372953
# 4         5.130650   -0.057569     -0.030008   0.396042   -1.491347
#
#    kurtZaccel  rangeZaccel  variationZaccel
# 0    0.544279     3.060726        -4.557892
# 1    0.936114     3.061306       -38.884676
# 2    7.715927     5.277242        -4.290775
# 3    7.632989     5.277242        -6.252671
# 4    9.065509     5.277242        -6.879401
#
# [5 rows x 23 columns]

# %%
# merge demographics df with features df

cols = ['healthCode','age', 'gender', 'professional-diagnosis']

# %%
actv_walk_final = actv_walk.merge(demographics_df[cols], on='healthCode', how='left')

# %%
actv_walk_final.head()
# Out:
#                                recordId                            healthCode  \
# 0  a3e54d84-360e-4e8a-9534-de188d5fa9e1  000240d1-1110-4dd2-a2d0-e344c37efd68
# 1  27d5ffdd-536e-4f2d-b478-74bbd520e9f7  00081bd9-9abd-4003-b035-de6cc3e8c922
# 2  cdd76ffc-9607-4106-b806-2fa29ad282f4  00372eda-3796-481b-96f7-f37e8e600904
# 3  ba735eb0-0639-4392-8d4d-f87b06c7b7e6  00372eda-3796-481b-96f7-f37e8e600904
# 4  2344a520-81df-4166-9f63-09343c502a21  00372eda-3796-481b-96f7-f37e8e600904
#
#    meanXaccel  medianXaccel  stdXaccel  skewXaccel  kurtXaccel  rangeXaccel  \
# 0   -0.060817     -0.039582   0.251105   -0.438470    0.141505     1.508230
# 1   -0.015293      0.019290   0.205124   -0.854834    1.367009     1.521156
# 2    0.013353      0.023553   0.206104   -0.969447    4.550264     2.571121
# 3    0.016124      0.023198   0.192878   -0.936322    4.949377     2.571121
# 4    0.013815      0.019293   0.198090   -0.664648    4.381479     2.674647
#
#    variationXaccel  meanYaccel           ...            meanZaccel  \
# 0        -4.128884    0.048314           ...             -0.104390
# 1       -13.413365    0.050700           ...             -0.009990
# 2        15.434469    0.047635           ...             -0.098005
# 3        11.962509    0.056733           ...             -0.068101
# 4        14.338761    0.048095           ...             -0.057569
#
#    medianZaccel  stdZaccel  skewZaccel  kurtZaccel  rangeZaccel  \
# 0     -0.152150   0.475797    0.726143    0.544279     3.060726
# 1      0.011845   0.388474    0.143198    0.936114     3.061306
# 2     -0.091900   0.420515   -1.091197    7.715927     5.277242
# 3     -0.036225   0.425813   -1.372953    7.632989     5.277242
# 4     -0.030008   0.396042   -1.491347    9.065509     5.277242
#
#    variationZaccel   age  gender  professional-diagnosis
# 0        -4.557892  33.0    Male                   False
# 1       -38.884676  70.0    Male                   False
# 2        -4.290775   NaN  Female                   False
# 3        -6.252671   NaN  Female                   False
# 4        -6.879401   NaN  Female                   False
#
# [5 rows x 26 columns]

# %%
# rearrange columns

first_four_cols = ['recordId', 'healthCode', 'age', 'gender']

final_cols = first_four_cols  + [col for col in actv_walk_final if col not in first_four_cols]
final_df = actv_walk_final[final_cols]

# %%
final_df.head()
# Out:
#                                recordId                            healthCode  \
# 0  a3e54d84-360e-4e8a-9534-de188d5fa9e1  000240d1-1110-4dd2-a2d0-e344c37efd68
# 1  27d5ffdd-536e-4f2d-b478-74bbd520e9f7  00081bd9-9abd-4003-b035-de6cc3e8c922
# 2  cdd76ffc-9607-4106-b806-2fa29ad282f4  00372eda-3796-481b-96f7-f37e8e600904
# 3  ba735eb0-0639-4392-8d4d-f87b06c7b7e6  00372eda-3796-481b-96f7-f37e8e600904
# 4  2344a520-81df-4166-9f63-09343c502a21  00372eda-3796-481b-96f7-f37e8e600904
#
#     age  gender  meanXaccel  medianXaccel  stdXaccel  skewXaccel  kurtXaccel  \
# 0  33.0    Male   -0.060817     -0.039582   0.251105   -0.438470    0.141505
# 1  70.0    Male   -0.015293      0.019290   0.205124   -0.854834    1.367009
# 2   NaN  Female    0.013353      0.023553   0.206104   -0.969447    4.550264
# 3   NaN  Female    0.016124      0.023198   0.192878   -0.936322    4.949377
# 4   NaN  Female    0.013815      0.019293   0.198090   -0.664648    4.381479
#
#    rangeXaccel           ...            rangeYaccel  variationYaccel  \
# 0     1.508230           ...               1.895134         6.525710
# 1     1.521156           ...               1.910760         5.276845
# 2     2.571121           ...               2.653296         4.846593
# 3     2.571121           ...               2.653296         3.992016
# 4     2.674647           ...               3.030658         5.130650
#
#    meanZaccel  medianZaccel  stdZaccel  skewZaccel  kurtZaccel  rangeZaccel  \
# 0   -0.104390     -0.152150   0.475797    0.726143    0.544279     3.060726
# 1   -0.009990      0.011845   0.388474    0.143198    0.936114     3.061306
# 2   -0.098005     -0.091900   0.420515   -1.091197    7.715927     5.277242
# 3   -0.068101     -0.036225   0.425813   -1.372953    7.632989     5.277242
# 4   -0.057569     -0.030008   0.396042   -1.491347    9.065509     5.277242
#
#    variationZaccel  professional-diagnosis
# 0        -4.557892                   False
# 1       -38.884676                   False
# 2        -4.290775                   False
# 3        -6.252671                   False
# 4        -6.879401                   False
#
# [5 rows x 26 columns]

# %%
# save as csv

#final_df.to_csv('final_df.csv')
